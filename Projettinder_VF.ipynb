# %% [markdown]
# IMPORTATION

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio
import plotly.offline as py
from plotly.subplots import make_subplots

# %% [markdown]
# # PART 1 : DATA OBSERVING
#
# Observe the dataset to understand it. Observe the columns to identify which ones are important and which ones are less important.

# %%
# Import and read dataset 
# Used the 'encoding='latin-1' to specify the correct encoding when reading my file because there was likely a character in the data that cannot be decoded using the UTF-8 encoding

dataset = pd.read_csv("Speed_Dating_Data.csv", encoding='latin-1')
dataset.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
# Display shape of the dataset

dataset.shape
# Out:
# (8378, 195)

# %%
# Display various statistics of the dataset

dataset.describe(include='all')
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  ...  \
# ...

# %%
# Display various informations about the dataset :

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
# Show columns of the dataset

dataset.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
# Display columns type

dataset.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
#              ...
# attr5_3     float64
# sinc5_3     float64
# intel5_3    float64
# fun5_3      float64
# amb5_3      float64
# Length: 195, dtype: object

# %% [markdown]
# To clean our dataset, I strated first by dropping the columns that seem not important to our project.
# I used the dropna method to do that

# %%
# Drop the columns we are not interested in :

dataset= dataset.drop(columns=['id','idg','condtn','position', 'positin1', 'order', 'partner', 'zipcode','income'])

# %%
print("The shape of the dataset is now :" ,dataset.shape)
print(" We went from 195 columns to 186 columns")
# Out:
# The shape of the dataset is now : (8378, 186)
#  We went from 195 columns to 186 columns

# %% [markdown]
# We then look for missing values in our dataset to know if we should clean the dataset or not.

# %%
pourcentage_missing = (dataset.isna().mean()*100).round(2)
pourcentage_total_missing=(dataset.isna().mean().mean()*100).round(2) 
print("Percentage of missing values is {}%" .format(pourcentage_total_missing))
print("{}% is a big percentage of missing values so we will have to clean that.".format(pourcentage_total_missing))
# Out:
# Percentage of missing values is 27.27%
# 27.27% is a big percentage of missing values so we will have to clean that.

# %%
# Deleting the missing values in our dataset : Deleting the columns where the percentage of missing values is more than 50% :

threshold= int(len(dataset)/2)

dataset.dropna(axis=1, thresh=threshold, inplace=True)

# %%
# Recalculating the percentage of missing values to see the results after cleaning :

pourcentage_missing = (dataset.isna().mean()*100).round(2)
pourcentage_total_missing=(dataset.isna().mean().mean()*100).round(2)

print("{}% is our new percentage of missing values.".format(pourcentage_total_missing))
# Out:
# 10.35% is our new percentage of missing values.

# %%
# Basic stats

print("Number of rows : {}".format(dataset.shape[0]))
print()

print("Number of columns : {}".format(dataset.shape[1]))
print()

print("Percentage of missing values: ")
display(100*dataset.isnull().sum()/dataset.shape[0])

print("Basics statistics: ")
data_desc = dataset.describe(include='all')
display(data_desc)
print()
# Out:
# Number of rows : 8378
#
# Number of columns : 127
#
# Percentage of missing values:
# iid          0.000000
# gender       0.000000
# wave         0.000000
# round        0.000000
# pid          0.119360
#               ...
# attr5_2     47.756028
# sinc5_2     47.756028
# intel5_2    47.756028
# fun5_2      47.756028
# amb5_2      47.756028
# Length: 127, dtype: float64
# Basics statistics:
#                 iid       gender         wave        round          pid  \
# count   8378.000000  8378.000000  8378.000000  8378.000000  8368.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     0.500597    11.350919    16.872046   283.863767
# std      158.583367     0.500029     5.995903     4.358458   158.584899
# min        1.000000     0.000000     1.000000     5.000000     1.000000
# ...

# %%
# Display shape of the dataset

print("Number of rows : {}".format(dataset.shape[0]))
print("Number of columns : {}".format(dataset.shape[1]))
# Out:
# Number of rows : 8378
# Number of columns : 127

# %% [markdown]
# Let's modify numbers in our dataset into their meaning

# %%
# gender : Female = 0 , Male = 1
dataset['gender'] = dataset['gender'].map({ 0 : "Female", 1 : "Male"})
# match : 1 = yes, 0 = no
dataset['match'] =dataset['match'].map({ 0 : "No", 1 : "Yes"})

# decision : 1 = yes, 0 = no
dataset['dec']  = dataset['dec'].map({ 0 : "No", 1 : "Yes"})

#  Same Race 1= yes, 0=no
dataset['samerace'] = dataset['samerace'].map({ 0 : "No", 1 : "Yes"})

# race : Black/African American = 1 , European/Caucasian-American = 2 , Latino/Hispanic American = 3 , 
# Asian/Pacific Islander/Asian-Americann = 4 , Native American = 5 
dataset["race"] = dataset["race"].apply(lambda x: 'Black/African American' if x == 1
                                  else 'European/Caucasian-American' if x == 2
                                  else 'Latino/Hispanic American' if x == 3
                                  else 'Asian/Pacific Islander/Asian-Americann' if x == 4
                                  else 'Native American' if x == 5
                                   else 'Other'
                                         )

dataset["goal"] = dataset["goal"].apply(lambda x: 'Seemed like a fun night out' if x == 1
                                  else 'To meet new people' if x == 2
                                  else 'To get a date' if x == 3
                                  else 'Looking for a serious relationship' if x == 4
                                  else 'To say I did it' if x == 5
                                   else 'Other'
                                         )

# %% [markdown]
# # VIZUALISATIONS

# %% [markdown]
# ### How many participants per gender ?

# %%
# Display number of participants  per gender :

dataset['gender'].value_counts()
# Out:
# gender
# Male      4194
# Female    4184
# Name: count, dtype: int64

# %%
# Display the participants per wave and by gender in a histogram :

import plotly.express as px

# Ensure the column values are consistent
print(dataset['gender'].unique())  # Check the unique values in the 'gender' column

# Adjust the color map to match the actual values in the 'gender' column
color_discrete_map = {'Women': '#8B0000', 'Men': '#00008B'}  # Use exact matching keys

# Create the histogram with the corrected color map
fig = px.histogram(
    dataset, 
    x='wave', 
    color='gender', 
    barmode='group', 
    title="Participants per wave by gender",
    color_discrete_map=color_discrete_map
)

fig.show()
# Out:
# ['Female' 'Male']

# %% [markdown]
# There were 21 waves of dates. We can conclude that there are as much women participants as men participants in every wave

# %% [markdown]
# ### What is the age of the participants ?

# %%
# let's display now the age of those participants in a box plot :

fig = px.box(dataset, y='age', title='Box Plot of Age')
fig.update_layout(width=500, height=500)
fig.show()

# %%
# Let's see this age distribution by gender :

import plotly.express as px

# Define the reversed color palettes for each gender

color_palette0 = px.colors.sequential.Blues[::-1]
color_palette1 = px.colors.sequential.Reds[::-1]


# Select specific colors for 'women' and 'men' from the palettes
color_discrete_map = {
    'women': color_palette0,  # Darkest red from the reversed palette
    'men': color_palette1   # Darkest blue from the reversed palette
}

# Create the histogram with the custom colors
fig = px.histogram(
    dataset,
    x='age',
    color='gender',
    width=700,
    height=500,
    color_discrete_map=color_discrete_map
)

fig.show()

# %% [markdown]
# We conclude : - Most people are between 24 and 28 years old - Minimum age is 18 yeals old - Maximun age is 55 years old

# %% [markdown]
# ### What is the race distribution ?

# %%
dataset["race"].value_counts()
# Out:
# race
# European/Caucasian-American               4727
# Asian/Pacific Islander/Asian-Americann    1982
# Latino/Hispanic American                   664
# Other                                      585
# Black/African American                     420
# Name: count, dtype: int64

# %%
color_palette = px.colors.sequential.Blues[::-1]

race = dataset["race"].value_counts(ascending=False)

trace = go.Pie(labels=race.index, values=race, marker=dict(colors=color_palette))

layout = go.Layout(
    title={'text': 'Distribution of the race of the participants', 'x': 0.5,'yanchor': 'top', 'y': 0.97},
    width=700, 
    height=500,
        legend=dict(
        x=0.9,
        y=0.3
    )
    )
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %% [markdown]
# ### What is the goal of participation in this event ?

# %%
# Display the number of participants ordered by the goal of the date :

dataset['goal'].value_counts()
# Out:
# goal
# Seemed like a fun night out           3426
# To meet new people                    3012
# To get a date                          631
# To say I did it                        510
# Other                                  498
# Looking for a serious relationship     301
# Name: count, dtype: int64

# %%
color_palette = px.colors.sequential.Blues[::-1]

goal = dataset["goal"].value_counts(ascending=False)

trace = go.Pie(labels=goal.index, values=goal, marker=dict(colors=color_palette))

layout = go.Layout(
    title={'text': 'Distribution of the goal of participation', 'x': 0.5,'yanchor': 'top', 'y': 0.97},
    width=700, 
    height=500,
        legend=dict(
        x=0.9,
        y=0.3
    )
    )
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %% [markdown]
# Most of the participants came to have a fun night out

# %% [markdown]
# ### What do males search for in a female partner ?
#  ### What do females search for in a male partner ?

# %%
# let's start by having a look at the columns we will need to answer this question :

a,b=1,1
attributes = [f'attr{a}_{b}',f'sinc{a}_{b}',f'intel{a}_{b}',f'fun{a}_{b}',f'amb{a}_{b}',f'shar{a}_{b}']
df_attributes = dataset[attributes]

print("df_attributes is :")
display(df_attributes)
print("Basic stats of df_attributes is :")
display(df_attributes.describe(include="all"))
# Out:
# df_attributes is :
#       attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# 0        15.0     20.0      20.0    15.0    15.0     15.0
# 1        15.0     20.0      20.0    15.0    15.0     15.0
# 2        15.0     20.0      20.0    15.0    15.0     15.0
# 3        15.0     20.0      20.0    15.0    15.0     15.0
# 4        15.0     20.0      20.0    15.0    15.0     15.0
# ...       ...      ...       ...     ...     ...      ...
# 8373     70.0      0.0      15.0    15.0     0.0      0.0
# 8374     70.0      0.0      15.0    15.0     0.0      0.0
# 8375     70.0      0.0      15.0    15.0     0.0      0.0
# 8376     70.0      0.0      15.0    15.0     0.0      0.0
# 8377     70.0      0.0      15.0    15.0     0.0      0.0
#
# [8378 rows x 6 columns]
# Basic stats of df_attributes is :
#            attr1_1      sinc1_1     intel1_1       fun1_1       amb1_1  \
# count  8299.000000  8299.000000  8299.000000  8289.000000  8279.000000
# ...

# %%
color_palette = px.colors.sequential.Blues[::-1]
df_attributes_sort = df_attributes.median().sort_values(ascending=False)
trace = go.Pie(labels=attributes, values=df_attributes_sort, marker=dict(colors=color_palette))

layout = go.Layout(
    title={'text': 'Distribution of the importance of attributes', 'x': 0.5,'yanchor': 'top', 'y': 0.97},
    width=700, 
    height=500,
        legend=dict(
        x=0.9,
        y=0.3
    )
    )
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %% [markdown]
# For both participants : attractivness and intelligence are the the most desirable attributes and ambitions and shared interests are the least desirable attributes.

# %% [markdown]
# Let's see this by gender

# %%
a,b=1,1
attributes = ['gender',f'attr{a}_{b}',f'sinc{a}_{b}',f'intel{a}_{b}',f'fun{a}_{b}',f'amb{a}_{b}',f'shar{a}_{b}']

df_attributes_gender = dataset[attributes].groupby('gender').median()


df_attributes_gender
# Out:
#         attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# gender
# Female   15.380    20.00      20.0   17.78    15.0    13.21
# Male     23.905    17.39      20.0   18.75    10.0    10.00

# %% [markdown]
# We can see that there is a bit of difference in the notations given my males and females. Let's visualize this in a graph

# %%
# Let's seperate female and male :

df_attributes_female = df_attributes_gender.iloc[[0]]
df_attributes_male = df_attributes_gender.iloc[[1]]

def sort_columns_by_values(df_attributes_gender):
    row_values = df_attributes_gender.iloc[0]
    sorted_columns = row_values.sort_values().index
    sorted_df_attributes= df_attributes_gender[sorted_columns]
    return sorted_df_attributes

sorted_df_attributes_female= sort_columns_by_values(df_attributes_female)
sorted_df_attributes_male=sort_columns_by_values(df_attributes_male)


print("df_attributes for females:")
display(sorted_df_attributes_female)
print()


print("df_attributes for males:")
display(sorted_df_attributes_male)
# Out:
# df_attributes for females:
#         shar1_1  amb1_1  attr1_1  fun1_1  sinc1_1  intel1_1
# gender
# Female    13.21    15.0    15.38   17.78     20.0      20.0
# df_attributes for males:
#         amb1_1  shar1_1  sinc1_1  fun1_1  intel1_1  attr1_1
# gender
# Male      10.0     10.0    17.39   18.75      20.0   23.905

# %%
# Using plotly express
color_palette0 = px.colors.sequential.Reds[::-1]
color_palette1 = px.colors.sequential.Blues[::-1]
# Females

fig = go.Figure()
fig.add_trace(go.Bar(x=sorted_df_attributes_female.columns, y=sorted_df_attributes_female.iloc[0], name='Female', marker_color=color_palette0)) 
fig.update_layout(title='The notation given by females for each attribute',  xaxis_title='Attributes', yaxis_title='Notation')
fig.show()

# Males
fig = go.Figure()
fig.add_trace(go.Bar(x=sorted_df_attributes_male.columns, y=sorted_df_attributes_male.iloc[0], name='Males', marker_color=color_palette1)) 
fig.update_layout(title='The notation given by males for each attribute', xaxis_title='Attributes', yaxis_title='Notation')
fig.show()

#Calcul des moyennes des notes attribuées par les participants 
color_palette0 = px.colors.sequential.Reds[::-1]
color_palette1 = px.colors.sequential.Blues[::-1]
# Assign colors from palettes to the gender keys in the color_discrete_map
color_discrete_map = {
    'Female': color_palette0[0],  # Choose a color from Reds palette
    'Male': color_palette1[0]    # Choose a color from Blues palette
}

# Create the bar plot
fig = px.bar(
    df_attributes_gender.T,
    barmode='group',
    title='The notation given by participants for each attributes per gender',
    color_discrete_map=color_discrete_map
)

# Update layout
fig.update_layout(
    xaxis_title='Attributes',
    yaxis_title='Notation'
)

# Show the plot
fig.show()

# %% [markdown]
# We conclude that males search for attractivness and intelligence in female partners.
# And females search for intelligence and sincerity in male partners.

# %% [markdown]
# ### What do people think the opposite sex wants from them ?

# %%
# let's start by having a look at the columns we will need to answer this question :

a,b=2,1
attributes = [f'attr{a}_{b}',f'sinc{a}_{b}',f'intel{a}_{b}',f'fun{a}_{b}',f'amb{a}_{b}',f'shar{a}_{b}']
df_attributes = dataset[attributes]
attributes = ['gender',f'attr{a}_{b}',f'sinc{a}_{b}',f'intel{a}_{b}',f'fun{a}_{b}',f'amb{a}_{b}',f'shar{a}_{b}']
df_attributes_gender = dataset[attributes].groupby('gender').mean()

df_attributes_female = df_attributes_gender.iloc[[0]]
df_attributes_male = df_attributes_gender.iloc[[1]]

def sort_columns_by_values(df_attributes_gender):
    row_values = df_attributes_gender.iloc[0]
    sorted_columns = row_values.sort_values().index
    sorted_df_attributes= df_attributes_gender[sorted_columns]
    return sorted_df_attributes

sorted_df_attributes_female= sort_columns_by_values(df_attributes_female)
sorted_df_attributes_male=sort_columns_by_values(df_attributes_male)

# %%
color_palette = px.colors.sequential.Reds[::-1]

trace = go.Pie(labels=sorted_df_attributes_female.columns, values=sorted_df_attributes_female.iloc[0], marker=dict(colors=color_palette))

layout = go.Layout(
    title={'text': 'Distribution of what females think the opposite sex want from them ', 'x': 0.5,'yanchor': 'top', 'y': 0.97},
    width=700, 
    height=500,
        legend=dict(
        x=0.9,
        y=0.3
    )
    )
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %%
color_palette = px.colors.sequential.Blues[::-1]

trace = go.Pie(labels=sorted_df_attributes_male.columns, values=sorted_df_attributes_male.iloc[0], marker=dict(colors=color_palette))

layout = go.Layout(
    title={'text': 'Distribution of what males think the opposite sex want from them ', 'x': 0.5,'yanchor': 'top', 'y': 0.97},
    width=700, 
    height=500,
        legend=dict(
        x=0.9,
        y=0.3
    )
    )
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %% [markdown]
# Both males and females think the opposite sex look for attractivness the most

# %% [markdown]
# ### Are shared interests more important than a shared racial background?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Define the Plotly color palette
color_palette = px.colors.sequential.Blues[::-1]

# Convert Plotly's RGB colors to hex format for Seaborn
hex_palette = [f"#{int(c[0]*255):02x}{int(c[1]*255):02x}{int(c[2]*255):02x}" 
               for c in [tuple(map(lambda x: int(x)/255, color.split('(')[1][:-1].split(','))) 
                         for color in color_palette]]

# Plot using the Seaborn-compatible hex palette
plt.figure(figsize=(12, 6))
plt.title("Race Similarity Importance", fontsize=18)
sns.countplot(x='imprace', data=dataset, palette=hex_palette)
plt.show()
#imprace:How important is it to you (on a scale of 1-10) that a person you date be of the same racial/ethnic background?

# %% [markdown]
# Most people don't care if they share the same race with their partner.

# %%
# Are shared interests more important than a shared racial background?

dataset['samerace_numeric'] = dataset['samerace'].map({'No':0, 'Yes':1 })
dataset['match_numeric'] = dataset['match'].map({'No':0, 'Yes':1 })
correlation= dataset[['shar1_1', 'samerace_numeric', 'match_numeric']].corr()
print(correlation)
# Out:
#                    shar1_1  samerace_numeric  match_numeric
# shar1_1           1.000000         -0.015006      -0.048318
# samerace_numeric -0.015006          1.000000       0.013028
# match_numeric    -0.048318          0.013028       1.000000

# %%
plt.figure(figsize=(10, 5))
plt.title('Correlation between shared interests, racial and match')
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
for i in range(correlation.shape[0]):
    for j in range(correlation.shape[1]):
        plt.text(j + 0.5, i + 0.5, f"{correlation.iloc[i, j]:.2f}", ha='center', va='center', color='black')
sns.heatmap(correlation, cmap='coolwarm' ,vmin=-0.1, vmax=0.2)
plt.show()

# %% [markdown]
# There is a weak correlation between matches and both shared interests and shared race. But shared race has a stronger correlation with match compared to shared interests.

# %% [markdown]
# ### Matches

# %%
import plotly.graph_objects as go
import plotly.express as px

# Define color palettes
color_palette0 = px.colors.sequential.Reds[::-1]
color_palette1 = px.colors.sequential.Greens[::-1]

# Map 'No' and 'Yes' to colors
color_discrete_map = {
    'No': color_palette0[0],  # Use the darkest red
    'Yes': color_palette1[0]  # Use the darkest green
}

# Get data for the pie chart
match_df = dataset['match'].value_counts()

# Assign colors based on labels
colors = [color_discrete_map[label] for label in match_df.index]

# Create the Pie chart
trace = go.Pie(
    labels=match_df.index,
    values=match_df.values,
    marker=dict(colors=colors)  # Set colors
)

# Define the layout
layout = go.Layout(
    title={'text': 'Proportion of Yes vs No for a match', 'x': 0.5, 'yanchor': 'top', 'y': 0.97},
    width=700,
    height=500,
    legend=dict(
        x=0.9,
        y=0.3
    )
)

# Create and show the figure
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %% [markdown]
# Only 16.5% matches

# %% [markdown]
# Let's show that per gender :

# %%
import plotly.express as px

# Define color mappings for gender and match categories
color_discrete_map = {
    'Female': px.colors.sequential.Reds[::-1][0],  # Darkest red for Female
    'Male': px.colors.sequential.Blues[::-1][0]  # Darkest blue for Male
}

# Create the histogram
fig = px.histogram(
    dataset,
    x='match',
    color='gender',  # Color by gender
    barmode='group',
    title="Matches per gender",
    color_discrete_map=color_discrete_map  # Apply the custom colors
)

# Show the figure
fig.show()

# %% [markdown]
# There is almost no diffenre between female decisions and male decisions. Females match and don't match as much as males.

# %% [markdown]
# ### Second date

# %%
df_second=dataset[dataset.date==2]

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# Define colors for genders in HEX format
color_palette = {
    'Male': '#08306b',  # Darkest blue (converted from Plotly palette)
    'Female': '#99000d'  # Darkest red (converted from Plotly palette)
}

# Get the counts of genders
gender_counts = df_second['gender'].value_counts()

# Map colors based on gender
colors = [color_palette[gender] for gender in gender_counts.index]

# Plot the bar chart
ax = gender_counts.plot(kind='bar',
                        figsize=(14, 8),
                        color=colors,  # Apply custom HEX colors
                        title="Count of second dates per gender")

# Add labels to bars
for i in ax.patches:
    ax.text(i.get_x() + i.get_width() / 2, i.get_height() + 0.1, 
            str(int(i.get_height())), ha='center', fontsize=10)

# Set labels
ax.set_ylabel('Counts')
ax.set_xlabel('Gender')

# Show the plot
plt.show()

# %% [markdown]
# Males go on second dates more than females.

# %% [markdown]
# ## What males think females look for is usually not what females are actually looking for :
# ##### Females look for intelligence the most in males but males think females look for attractiveness
# ## Females and males don’t look for the same attributes in the opposite sex :
# ##### Females look for intelligence while males look for attractiveness
# ## 40% of the participant participate because they think it is a fun night out
